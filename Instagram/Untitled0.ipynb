# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm

# %%
df = pd.read_csv('output_sample/1.csv')
df.head()
# Out:
#                                            Photo URL         created_time  \
# 0  http://scontent-a.cdninstagram.com/hphotos-xaf...  2014-12-12 14:51:13
# 1  http://scontent-a.cdninstagram.com/hphotos-xaf...  2014-12-12 14:51:08
# 2  http://scontent-b.cdninstagram.com/hphotos-xfa...  2014-12-12 14:51:07
# 3  http://scontent-a.cdninstagram.com/hphotos-xfa...  2014-12-12 14:51:07
# 4  http://scontent-b.cdninstagram.com/hphotos-xaf...  2014-12-12 14:51:06
#
#                                             Location  Zip Code  Like Count  \
# 0  Location: 214805307 (Point: (40.758614, -73.98...     10001           0
# 1  Location: 0 (Point: (40.754867432, -73.9918220...     10001           0
# 2  Location: 243839297 (Point: (40.765105, -73.97...     10001           0
# 3  Location: 0 (Point: (40.741217035, -74.0047046...     10001           0
# 4  Location: 3328166 (Point: (40.738205, -73.9904...     10001           0
#
#                                             hashtags  \
# ...

# %%
df = df.drop(['Photo URL'], axis=1)
df.head()
# Out:
#           created_time                                           Location  \
# 0  2014-12-12 14:51:13  Location: 214805307 (Point: (40.758614, -73.98...
# 1  2014-12-12 14:51:08  Location: 0 (Point: (40.754867432, -73.9918220...
# 2  2014-12-12 14:51:07  Location: 243839297 (Point: (40.765105, -73.97...
# 3  2014-12-12 14:51:07  Location: 0 (Point: (40.741217035, -74.0047046...
# 4  2014-12-12 14:51:06  Location: 3328166 (Point: (40.738205, -73.9904...
#
#    Zip Code  Like Count                                           hashtags  \
# 0     10001           0  ['#alleredeintegreret', '#48.etage', '#firstle...
# 1     10001           0  ['#truth', '#preach', '#life', '#growingup', '...
# 2     10001           0                                     ['#TheAvenue']
# 3     10001           0      ['#NestFireTruck!!', '#BrandAmbassadorsFTW"']
# 4     10001           0                                      ['#setlife"']
#
#                                              caption
# ...

# %%
df = df.drop(['Like Count'], axis=1)
df.head()
# Out:
#           created_time                                           Location  \
# 0  2014-12-12 14:51:13  Location: 214805307 (Point: (40.758614, -73.98...
# 1  2014-12-12 14:51:08  Location: 0 (Point: (40.754867432, -73.9918220...
# 2  2014-12-12 14:51:07  Location: 243839297 (Point: (40.765105, -73.97...
# 3  2014-12-12 14:51:07  Location: 0 (Point: (40.741217035, -74.0047046...
# 4  2014-12-12 14:51:06  Location: 3328166 (Point: (40.738205, -73.9904...
#
#    Zip Code                                           hashtags  \
# 0     10001  ['#alleredeintegreret', '#48.etage', '#firstle...
# 1     10001  ['#truth', '#preach', '#life', '#growingup', '...
# 2     10001                                     ['#TheAvenue']
# 3     10001      ['#NestFireTruck!!', '#BrandAmbassadorsFTW"']
# 4     10001                                      ['#setlife"']
#
#                                              caption
# 0  Comment: malourohde said "Første aften i New Y...
# ...

# %%
df = df.dropna()
df.head()
# Out:
#           created_time                                           Location  \
# 0  2014-12-12 14:51:13  Location: 214805307 (Point: (40.758614, -73.98...
# 1  2014-12-12 14:51:08  Location: 0 (Point: (40.754867432, -73.9918220...
# 2  2014-12-12 14:51:07  Location: 243839297 (Point: (40.765105, -73.97...
# 3  2014-12-12 14:51:07  Location: 0 (Point: (40.741217035, -74.0047046...
# 4  2014-12-12 14:51:06  Location: 3328166 (Point: (40.738205, -73.9904...
#
#    Zip Code                                           hashtags  \
# 0     10001  ['#alleredeintegreret', '#48.etage', '#firstle...
# 1     10001  ['#truth', '#preach', '#life', '#growingup', '...
# 2     10001                                     ['#TheAvenue']
# 3     10001      ['#NestFireTruck!!', '#BrandAmbassadorsFTW"']
# 4     10001                                      ['#setlife"']
#
#                                              caption
# 0  Comment: malourohde said "Første aften i New Y...
# ...

# %%
splits = df['caption'].str.split(' ')
df['user'] = splits.str[1]
df.head()
# Out:
#           created_time                                           Location  \
# 0  2014-12-12 14:51:13  Location: 214805307 (Point: (40.758614, -73.98...
# 1  2014-12-12 14:51:08  Location: 0 (Point: (40.754867432, -73.9918220...
# 2  2014-12-12 14:51:07  Location: 243839297 (Point: (40.765105, -73.97...
# 3  2014-12-12 14:51:07  Location: 0 (Point: (40.741217035, -74.0047046...
# 4  2014-12-12 14:51:06  Location: 3328166 (Point: (40.738205, -73.9904...
#
#    Zip Code                                           hashtags  \
# 0     10001  ['#alleredeintegreret', '#48.etage', '#firstle...
# 1     10001  ['#truth', '#preach', '#life', '#growingup', '...
# 2     10001                                     ['#TheAvenue']
# 3     10001      ['#NestFireTruck!!', '#BrandAmbassadorsFTW"']
# 4     10001                                      ['#setlife"']
#
#                                              caption             user
# 0  Comment: malourohde said "Første aften i New Y...       malourohde
# ...

# %%
df['Zip Code'].value_counts().plot(kind = 'bar')

# %%
user_list = list(set(df.user))
import csv
f = open('user.csv','w')
writer = csv.writer(f)
writer.writerow(user_list)
f.close()
