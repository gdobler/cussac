# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm
from KaggleAux import predict as ka # see github.com/agconti/kaggleaux for more details
# Out:
# /home/rybo/anaconda/lib/python2.7/site-packages/setuptools-7.0-py2.7.egg/pkg_resources.py:1045: UserWarning: /home/rybo/.python-eggs is writable by group/others and vulnerable to attack when used with get_resource_filename. Consider a more secure location (set with .set_extraction_path or the PYTHON_EGG_CACHE environment variable).

# %%
df = pd.read_csv('output/13.csv')

# %%
df.tail()
# Out:
#                                                Photo URL         created_time  \
# 69449  http://scontent-b.cdninstagram.com/hphotos-xaf...  2015-01-01 04:45:23
# 69450  http://scontent-b.cdninstagram.com/hphotos-xfa...  2015-01-01 04:45:33
# 69451  http://scontent-b.cdninstagram.com/hphotos-xaf...  2015-01-01 04:45:21
# 69452  http://scontent-b.cdninstagram.com/hphotos-xaf...  2015-01-01 04:45:19
# 69453  http://scontent-b.cdninstagram.com/hphotos-xaf...  2015-01-01 04:45:08
#
#                                                 Location  Zip Code  \
# 69449  Location: 0 (Point: (40.751083333, -73.7516783...     11423
# 69450     Location: 0 (Point: (40.6635754, -73.8837455))     11424
# 69451  Location: 0 (Point: (40.656975602, -73.9056858...     11424
# 69452  Location: 0 (Point: (40.631227108, -73.90164081))     11424
# 69453  Location: 0 (Point: (40.634945263, -73.9097938...     11424
#
#        Like Count   hashtags  \
# 69449           0         []
# 69450           0         []
# 69451           0  ['#NYE"']
# 69452           0         []
# 69453           0         []
#
#                                                  caption
# 69449  Comment: dm1204 said "Happy New Years from all...
# 69450  Comment: darkshades_eazye said "Happy New Year...
# 69451                Comment: _ashlayyyyyy said "🎉 #NYE"
# 69452                                                NaN
# 69453  Comment: buh_lenciaga said "Hay bestfrannnnn !...

# %%
df = df.drop(['Photo URL','Like Count'], axis = 1)

# %%
df.head()
# Out:
#           created_time                                           Location  \
# 0  2014-12-31 21:49:56  Location: 0 (Point: (40.764763333, -73.9939416...
# 1  2014-12-31 21:49:55  Location: 0 (Point: (40.73329248, -73.974673592))
# 2  2014-12-31 21:49:55  Location: 2745664 (Point: (40.77439551, -73.96...
# 3  2014-12-31 21:49:54  Location: 0 (Point: (40.714280819, -73.9595124...
# 4  2014-12-31 21:49:53  Location: 101380 (Point: (40.756359, -73.989055))
#
#    Zip Code                                           hashtags  \
# 0     10001  ['#tomtom', '#2015', '#nye', '#party', '#cats'...
# 1     10001                           ['#nyc', '#helicopter"']
# 2     10001                 ['#2015', '#NYE', '#Popfizzclink']
# 3     10001          ['#katharinehepburn', '#future', '#nye"']
# 4     10001               ['#NewYorkCity', '#MadameTussauds"']
#
#                                              caption
# 0  Comment: kmvoytko said "I can haz 2015? 🎉@tomm...
# 1  Comment: samuelcharlesross said "Chopper over ...
# 2  Comment: rachel_jill said "All in a days work!...
# 3  Comment: abbycarnevalejewelry said "New Year's...
# 4  Comment: brandinho0909 said "Sorry ladies, Tay...

# %%
df = df.dropna()

# %%
df.tail()
# Out:
#               created_time                                           Location  \
# 69448  2015-01-01 04:45:24  Location: 0 (Point: (40.754667008, -73.8128033...
# 69449  2015-01-01 04:45:23  Location: 0 (Point: (40.751083333, -73.7516783...
# 69450  2015-01-01 04:45:33     Location: 0 (Point: (40.6635754, -73.8837455))
# 69451  2015-01-01 04:45:21  Location: 0 (Point: (40.656975602, -73.9056858...
# 69453  2015-01-01 04:45:08  Location: 0 (Point: (40.634945263, -73.9097938...
#
#        Zip Code   hashtags                                            caption
# 69448     11423         []  Comment: vvxnn said "kik ; heyy_boii \n# ; 347...
# 69449     11423         []  Comment: dm1204 said "Happy New Years from all...
# 69450     11424         []  Comment: darkshades_eazye said "Happy New Year...
# 69451     11424  ['#NYE"']                Comment: _ashlayyyyyy said "🎉 #NYE"
# 69453     11424         []  Comment: buh_lenciaga said "Hay bestfrannnnn !...

# %%
splits = df['caption'].str.split(' ')
df['user'] = splits.str[1]
df.head()
# Out:
#           created_time                                           Location  \
# 0  2014-12-31 21:49:56  Location: 0 (Point: (40.764763333, -73.9939416...
# 1  2014-12-31 21:49:55  Location: 0 (Point: (40.73329248, -73.974673592))
# 2  2014-12-31 21:49:55  Location: 2745664 (Point: (40.77439551, -73.96...
# 3  2014-12-31 21:49:54  Location: 0 (Point: (40.714280819, -73.9595124...
# 4  2014-12-31 21:49:53  Location: 101380 (Point: (40.756359, -73.989055))
#
#    Zip Code                                           hashtags  \
# 0     10001  ['#tomtom', '#2015', '#nye', '#party', '#cats'...
# 1     10001                           ['#nyc', '#helicopter"']
# 2     10001                 ['#2015', '#NYE', '#Popfizzclink']
# 3     10001          ['#katharinehepburn', '#future', '#nye"']
# 4     10001               ['#NewYorkCity', '#MadameTussauds"']
#
#                                              caption                  user
# 0  Comment: kmvoytko said "I can haz 2015? 🎉@tomm...              kmvoytko
# 1  Comment: samuelcharlesross said "Chopper over ...     samuelcharlesross
# 2  Comment: rachel_jill said "All in a days work!...           rachel_jill
# 3  Comment: abbycarnevalejewelry said "New Year's...  abbycarnevalejewelry
# 4  Comment: brandinho0909 said "Sorry ladies, Tay...         brandinho0909

# %%
df['created_time'] = pd.to_datetime(df['created_time'], format = "%Y-%m-%d %H:%M:%S")
#df = df[df['timestamp']> "2000-01-01 00:00:00"]
df['created_time'] = df['created_time'].apply(lambda x: x.strftime('%m-%d-%Y %H %p'))

# %%
df.head()
# Out:
#        created_time                                           Location  \
# 0  12-31-2014 21 PM  Location: 0 (Point: (40.764763333, -73.9939416...
# 1  12-31-2014 21 PM  Location: 0 (Point: (40.73329248, -73.974673592))
# 2  12-31-2014 21 PM  Location: 2745664 (Point: (40.77439551, -73.96...
# 3  12-31-2014 21 PM  Location: 0 (Point: (40.714280819, -73.9595124...
# 4  12-31-2014 21 PM  Location: 101380 (Point: (40.756359, -73.989055))
#
#    Zip Code                                           hashtags  \
# 0     10001  ['#tomtom', '#2015', '#nye', '#party', '#cats'...
# 1     10001                           ['#nyc', '#helicopter"']
# 2     10001                 ['#2015', '#NYE', '#Popfizzclink']
# 3     10001          ['#katharinehepburn', '#future', '#nye"']
# 4     10001               ['#NewYorkCity', '#MadameTussauds"']
#
#                                              caption                  user
# 0  Comment: kmvoytko said "I can haz 2015? 🎉@tomm...              kmvoytko
# 1  Comment: samuelcharlesross said "Chopper over ...     samuelcharlesross
# 2  Comment: rachel_jill said "All in a days work!...           rachel_jill
# 3  Comment: abbycarnevalejewelry said "New Year's...  abbycarnevalejewelry
# 4  Comment: brandinho0909 said "Sorry ladies, Tay...         brandinho0909

# %%
df['created_time'].value_counts().plot(kind = 'barh')

# %%
df = df.drop(['caption'], axis = 1)

# %%
df.head(25)
splits = df['Location'].str.split(' ')
#print splits.str[3]
for i in splits.str[3].head():
    print i[1:-1]
for i in splits.str[4].head():
    print i[1:-2]
# Out:
# 40.764763333
# 40.73329248
# 40.77439551
# 40.714280819
# 40.756359
# 73.993941667
# 73.974673592
# 73.963908387
# 73.959512488
# 73.989055

# %%
df['Zip Code'].value_counts().head(10).plot(kind = 'barh')

# %%
df['hashtags'] = df['hashtags'].str[1:-1]
splits = df['hashtags'].str.split(',')
d = {}
for i in splits:
    for j in i:
        count = d.setdefault(j, 0)
        d[j] = count + 1
key = d.keys()
value = d.values()
df2 = pd.DataFrame({'Key':key,'Value':value})
df2.dropna()
df2 = df2[df2['Key']!='']
df2 = df2.sort(['Value'], ascending = False)
df2.head()
df2 = df2[df2['Key'].str.len() >3]
df2.head()
#df2['Key'] = df2['Key'].str.lstrip('\'#')
#df2.tail()
#df.head()
# Out:
#                     Key  Value
# 43623           '#2015'   1911
# 3231             '#nyc'   1816
# 40712            '#nye'   1079
# 9503           '#2015"'    967
# 6957    '#happynewyear'    787

# %%
df2['Key'] = df2['Key'].str[2:-1]

# %%
print df2.head(20)
# Out:
#                   Key  Value
# 43623           #2015   1911
# 3231             #nyc   1816
# 40712            #nye   1079
# 9503           #2015"    967
# 6957    #happynewyear    787
# 28881            #NYC    757
# 44115    #newyearseve    754
# 35119        #newyork    740
# 34778             nye    679
# 9109              NYE    673
# 15775            #NYE    661
# 38776            2015    633
# 41019           #love    572
# 14147        #newyear    561
# 39112           #2014    550
# 10833    happynewyear    540
# 2971            #nyc"    524
# 33445       #newyears    493
# 47984             nyc    454
# 2487   #happynewyear"    355

# %%
key = list(df2.Key.head(20))
value = list(df2.Value.head(20))
x = [i for i in xrange(10)]
#print key
#print value
h = plt.bar(xrange(len(key)), value, label = key)
xticks_pos = [0.65*patch.get_width() + patch.get_xy()[0] for patch in h]
plt.xticks(xticks_pos, key, ha = 'center', rotation = 90)
# Out:
# ([<matplotlib.axis.XTick at 0x7f1921c5ac90>,
#   <matplotlib.axis.XTick at 0x7f1921c5afd0>,
#   <matplotlib.axis.XTick at 0x7f1921ddd190>,
#   <matplotlib.axis.XTick at 0x7f1921d2cd10>,
#   <matplotlib.axis.XTick at 0x7f191f792490>,
#   <matplotlib.axis.XTick at 0x7f191f792bd0>,
#   <matplotlib.axis.XTick at 0x7f191f783350>,
#   <matplotlib.axis.XTick at 0x7f191f783a90>,
#   <matplotlib.axis.XTick at 0x7f191de94210>,
#   <matplotlib.axis.XTick at 0x7f191de94950>,
#   <matplotlib.axis.XTick at 0x7f191de720d0>,
#   <matplotlib.axis.XTick at 0x7f191de72810>,
#   <matplotlib.axis.XTick at 0x7f191de72f50>,
#   <matplotlib.axis.XTick at 0x7f191e5d66d0>,
#   <matplotlib.axis.XTick at 0x7f191e5d6e10>,
#   <matplotlib.axis.XTick at 0x7f191e5ae590>,
#   <matplotlib.axis.XTick at 0x7f1921c5a410>,
#   <matplotlib.axis.XTick at 0x7f1921c14d50>,
#   <matplotlib.axis.XTick at 0x7f1921be1950>,
#   <matplotlib.axis.XTick at 0x7f1921b5a190>],
#  <a list of 20 Text xticklabel objects>)

# %%
l1 = ["#2015","#nye","#2015\"","#nye\"","2015\"","#happynewyear","#newyearseve","nye","NYE","#NYE","2015","#newyear","#2014","happynewyear","#newyears","nyc","#happynewyear\""]
a = []
l2 = []
for i in l1:
    l2.append(i.lower())
#print l1
#df2['Class'] = df[]
for i in df2.Key:
    if str(i).lower() in l2:
        a.append(0)
        #print "Hi"
    elif "newyear" in str(i).lower():
        a.append(0)
    else:
        a.append(1)
df2['Class'] = a
df2.head(50)
# Out:
#                   Key  Value  Class
# 43623           #2015   1911      0
# 3231             #nyc   1816      1
# 40712            #nye   1079      0
# 9503           #2015"    967      0
# 6957    #happynewyear    787      0
# 28881            #NYC    757      1
# 44115    #newyearseve    754      0
# 35119        #newyork    740      1
# 34778             nye    679      0
# 9109              NYE    673      0
# 15775            #NYE    661      0
# 38776            2015    633      0
# 41019           #love    572      1
# 14147        #newyear    561      0
# 39112           #2014    550      0
# 10833    happynewyear    540      0
# 2971            #nyc"    524      1
# 33445       #newyears    493      0
# 47984             nyc    454      0
# 2487   #happynewyear"    355      0
# 35865       #brooklyn    321      1
# 46922           #nye"    320      0
# 21899    #newyorkcity    307      1
# 40025           2015"    285      0
# 40723      #instagood    283      1
# 22202             NYC    273      0
# 42992            #NYE    262      0
# 32849           #NYC"    258      1
# 42730         #family    252      1
# 25404   #HappyNewYear    250      0
# 23323          #happy    243      1
# 35638          #party    239      1
# 37280      #manhattan    230      1
# 32339        #NewYork    229      1
# 22598     newyearseve    229      0
# 44770        #friends    217      1
# 40841           #NYE"    215      0
# 3249    #happynewyear    213      0
# 36286  #photooftheday    211      1
# 28528         newyear    210      0
# 19994            2014    209      1
# 8064         #fashion    208      1
# 2579             NYE"    206      1
# 31220         #selfie    206      1
# 1942              #ny    184      1
# 44751    #NewYearsEve    180      0
# 3032     HappyNewYear    179      0
# 17532    #timessquare    176      1
# 30265   #newyearseve"    174      0
# 5874         newyears    171      0

# %%
df2.to_csv('new year.csv')
